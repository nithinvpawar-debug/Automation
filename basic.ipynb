# %%
2 + 3
# Out:
# 5

# %%
2 * 2
# Out:
# 4

# %%
100 / 50
# Out:
# 2.0

# %%
100 / 7
# Out:
# 14.285714285714286

# %%
100 & 7
# Out:
# 4

# %%
5 ** 3
# Out:
# 125

# %%
500 * (20 - 5) / 5
# Out:
# 1500.0

# %%
cost_of_ice_bag = 1.25

# %%
profit_margin = .2

# %%
number_of_bags = 500

# %%
profit_margin
# Out:
# 0.2

# %%
profit_per_bag
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 profit_per_bag
#
# NameError: name 'profit_per_bag' is not defined

# %%
total_profit = number_of_bag + cost_of_margin
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 total_profit = number_of_bag + cost_of_margin
#
# NameError: name 'number_of_bag' is not defined

# %%
profit_per_bag = cost_of_ice_bag + profit_margin

# %%
profit_per_bag
# Out:
# 1.45

# %%
total_profit = number_of_bags * profit_per_bag

# %%
total_profit
# Out:
# 725.0

# %%
net_profit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 net_profit
#
# NameError: name 'net_profit' is not defined

# %%
total_profit = net_profit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 total_profit = net_profit
#
# NameError: name 'net_profit' is not defined

# %%
total_profit
# Out:
# 725.0

# %%
print("nithin v pawar")
# Out:
# nithin v pawar

# %%
print("the total profit of the given data is", total_profit)
# Out:
# the total profit of the given data is 725.0

# %%
cost_of_ice_bag
+
profit_margin
+
number_of_bags
+
total_profit
# Out:
#   Cell In[55], line 2
#     +
#      ^
# SyntaxError: invalid syntax

# %% [markdown]
# my_fav_number = 1
# my_least_fav_number = 5
# my_neutral_number = 3
